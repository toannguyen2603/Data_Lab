# %% [markdown]
# # Components of Time Serie

# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plot

# %%
#Example_1
df_vacation = pd.read_csv("df_vacation.csv", parse_dates=['Month'], index_col=0)
df_vacation
# Out:
#             Num_Search_Vacation
# Month
# 2004-01-01                   94
# 2004-02-01                   89
# 2004-03-01                   86
# 2004-04-01                   79
# 2004-05-01                   89
# ...                         ...
# 2019-06-01                   58
# 2019-07-01                   56
# 2019-08-01                   45
# 2019-09-01                   38
# 2019-10-01                   37
#
# [190 rows x 1 columns]

# %%
plot.style.use('bmh')
ax = df_vacation.plot(color='red', grid=True, figsize=(8,5))
ax.set_xlabel('Year')
ax.set_ylabel('Number of Searches')
ax.set_title('Google Trend of Vacation in 2018')
# Out:
# Text(0.5, 1.0, 'Google Trend of Vacation in 2018')

# %%
#Example_2
df_furniture = pd.read_csv("./data_sec2/df_furniture.csv", parse_dates=['Month'], index_col=0)
df_furniture.head()
# Out:
#             furniture_price_adjusted
# Month
# 1992-01-01               2073.432724
# 1992-02-01               2114.485812
# 1992-03-01               2260.570891
# 1992-04-01               2255.103236
# 1992-05-01               2331.414618

# %%
plot.style.use('seaborn-deep')
ax = df_furniture.plot(color='green', grid=True, figsize=(8,5))
ax.set_xlabel('Year')
ax.set_ylabel('Millions of Dollars')
ax.set_title('Retail Sales of Furniture and Home Furnishings Stores')
# Out:
# Text(0.5, 1.0, 'Retail Sales of Furniture and Home Furnishings Stores')

# %%
#Example_3
df_bac = pd.read_csv("./data_sec2/df_bankofamerica.csv", parse_dates=['Date'], index_col=0)
df_bac.head()
# Out:
#             Adj Close Price
# Date
# 1990-01-02         1.711862
# 1990-01-03         1.725632
# 1990-01-04         1.688917
# 1990-01-05         1.652200
# 1990-01-08         1.661379

# %%
plot.style.use('seaborn-bright')
ax = df_bac.plot(color='brown', grid=True, figsize=(8,5))
ax.set_xlabel('Year')
ax.set_ylabel('Price in US Dollars')
ax.set_title('Adjusted Closing Price for Bank of America')
# Out:
# Text(0.5, 1.0, 'Adjusted Closing Price for Bank of America')

# %%
#Example_4
df_jpm = pd.read_csv("./data_sec2/df_jpmorgan.csv", parse_dates=['Date'], index_col=0)
df_jpm
# Out:
#             Adj Close Price
# Date
# 1990-01-02         3.610043
# 1990-01-03         3.730377
# 1990-01-04         3.745418
# 1990-01-05         3.760463
# 1990-01-08         3.760463
# ...                     ...
# 2019-10-10       114.209999
# 2019-10-11       116.139999
# 2019-10-14       116.449997
# 2019-10-15       119.959999
# 2019-10-16       119.680000
#
# [7507 rows x 1 columns]

# %%
plot.style.use('tableau-colorblind10')
ax = df_jpm.plot(color='purple', grid=True, figsize=(8,5))
ax.set_xlabel('Year')
ax.set_ylabel('Price in US Dollars')
ax.set_title('Adjusted Closing Price for J.P. Morgan')
# Out:
# Text(0.5, 1.0, 'Adjusted Closing Price for J.P. Morgan')

# %%
#Example_5
df_temp = pd.read_csv("./data_sec2/df_temp.csv", parse_dates=['Date'], index_col=0)
df_temp
# Out:
#             Value
# Date
# 1938-04-01   56.5
# 1938-05-01   64.7
# 1938-06-01   73.5
# 1938-07-01   80.4
# 1938-08-01   81.3
# ...           ...
# 2018-09-01   74.8
# 2018-10-01   59.6
# 2018-11-01   38.9
# 2018-12-01   39.0
# 2019-01-01   30.8
#
# [970 rows x 1 columns]

# %%
plot.style.use('fast')
ax = df_temp.plot(color='orange', grid=True, figsize=(8,5))
ax.set_xlabel('Year')
ax.set_ylabel('Fahrenheit')
ax.set_title('Average Temperature of St.Louis')
# Out:
# Text(0.5, 1.0, 'Average Temperature of St.Louis')

# %% [markdown]
# # Decomposing Time Series

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
ts1 = df_vacation['Num_Search_Vacation']

result = seasonal_decompose(ts1, model='additive', period=12)
print(result.trend)
print(result.seasonal)
print(result.resid)
print(result.observed)
# Out:
# Month
# 2004-01-01   NaN
# 2004-02-01   NaN
# 2004-03-01   NaN
# 2004-04-01   NaN
# 2004-05-01   NaN
#               ..
# 2019-06-01   NaN
# 2019-07-01   NaN
# 2019-08-01   NaN
# 2019-09-01   NaN
# 2019-10-01   NaN
# Name: trend, Length: 190, dtype: float64
# Month
# 2004-01-01    10.648661
# 2004-02-01     5.320883
# 2004-03-01     5.079216
# 2004-04-01    -0.259673
# 2004-05-01     3.574851
#                 ...
# 2019-06-01    14.530208
# 2019-07-01    13.501438
# 2019-08-01    -0.609673
# 2019-09-01   -14.868006
# 2019-10-01   -17.076339
# Name: seasonal, Length: 190, dtype: float64
# Month
# 2004-01-01   NaN
# 2004-02-01   NaN
# 2004-03-01   NaN
# 2004-04-01   NaN
# 2004-05-01   NaN
#               ..
# 2019-06-01   NaN
# 2019-07-01   NaN
# 2019-08-01   NaN
# 2019-09-01   NaN
# 2019-10-01   NaN
# Name: resid, Length: 190, dtype: float64
# Month
# 2004-01-01    94.0
# 2004-02-01    89.0
# 2004-03-01    86.0
# 2004-04-01    79.0
# 2004-05-01    89.0
#               ...
# ...

# %%
#Example_1
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams

rcParams['figure.figsize'] = 6,8
plot.style.use('Solarize_Light2')

ts1 = df_vacation['Num_Search_Vacation']

result = seasonal_decompose(ts1, model='additive', period=12)
result.plot()
plot.show()

# %%
#Example_2
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams

rcParams['figure.figsize'] = 6,8
plot.style.use('Solarize_Light2')

ts2 = df_furniture['furniture_price_adjusted']

result = seasonal_decompose(ts2, model='additive', period=12)
result.plot()
plot.show()

# %%
#Example_3
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams

rcParams['figure.figsize'] = 6,8
plot.style.use('Solarize_Light2')

ts3 = df_bac['Adj Close Price']

result = seasonal_decompose(ts3, model='additive', period=365)
result.plot()
plot.show()

# %%
#Example_4
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
from pylab import rcParams

rcParams['figure.figsize'] = 6,8
plot.style.use('bmh')

ts4 = df_jpm['Adj Close Price']

result = seasonal_decompose(ts4, model='additive', period=365)
result.plot()
plot.show()

# %%
#Example_5
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
from pylab import rcParams

rcParams['figure.figsize'] = 6,8
plot.style.use('Solarize_Light2')

ts5 = df_temp['Value']

result = seasonal_decompose(ts5, model='additive', period=12)
result.plot()
plot.show()

# %% [markdown]
# # Application of Multiplicative Model

# %%
#Example_1
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
from pylab import rcParams

rcParams['figure.figsize'] = 6,8
plot.style.use('bmh')

ts1 = df_vacation['Num_Search_Vacation']

result = seasonal_decompose(ts1, model='multiplicative', period=12)
result.plot()
plot.show()

# %%
#Example_2
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
from pylab import rcParams

rcParams['figure.figsize'] = 6,8
plot.style.use('bmh')

ts2 = df_furniture['furniture_price_adjusted']

result = seasonal_decompose(ts2, model='multiplicative', period=12)
result.plot()
plot.show()

# %%
#Example_3
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
from pylab import rcParams

rcParams['figure.figsize'] = 6,8
plot.style.use('bmh')

ts3 = df_bac['Adj Close Price']

result = seasonal_decompose(ts3, model='multiplicative', period=365)
result.plot()
plot.show()

# %%
#Example_4
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
from pylab import rcParams

rcParams['figure.figsize'] = 6,8
plot.style.use('bmh')

ts4 = df_jpm['Adj Close Price']

result = seasonal_decompose(ts4, model='multiplicative', period=365)
result.plot()
plot.show()

# %%
#Example_5
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
from pylab import rcParams

rcParams['figure.figsize'] = 6,8
plot.style.use('bmh')

ts5 = df_temp['Value']

result = seasonal_decompose(ts5, model='multiplicative', period=12)
result.plot()
plot.show()

# %% [markdown]
# # Page 29

# %%
import statsmodels
from statsmodels.tsa.arima_model import ARMA

# %%
from statsmodels.tsa.arima_process import arma_generate_sample
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(41)

ar_coefs = [1]
ma_coefs = [1,-0.8]
data = arma_generate_sample(ar_coefs,ma_coefs,nsample=100)

plt.plot(data)
plt.ylabel(r'$y_t$')
plt.xlabel(r'$t$')
plt.show()

# %%
from statsmodels.tsa.arima_process import arma_generate_sample
np.random.seed(42)

ar_coefs = [1,-0.3,-0.2]
ma_coefs = [1]

data = arma_generate_sample(ar_coefs,ma_coefs,nsample=100)

plt.plot(data)
plt.ylabel(r'$y_t$')
plt.xlabel(r'$t$')
# Out:
# Text(0.5, 0, '$t$')

# %%
from statsmodels.tsa.arima_process import arma_generate_sample
np.random.seed(43)

ar_coefs = [1,0.3]
ma_coefs = [1,0.2,0.4]

data = arma_generate_sample(ar_coefs,ma_coefs,nsample=100)

plt.plot(data)
plt.ylabel(r'$y_t$')
plt.xlabel(r'$t$')
# Out:
# Text(0.5, 0, '$t$')

# %% [markdown]
# # Introduction to moving average

# %%
from pandas import read_csv
from matplotlib import pyplot

# %% [markdown]
# # Exercise 1: Vacation dataset

# %%
vacation = read_csv('df_vacation.csv', index_col=0,parse_dates=True)
vacation.head()
# Out:
#             Num_Search_Vacation
# Month
# 2004-01-01                   94
# 2004-02-01                   89
# 2004-03-01                   86
# 2004-04-01                   79
# 2004-05-01                   89

# %%
from statsmodels.tsa.arima_model import ARMA

mod = ARMA(vacation,order=(0,1))
res = mod.fit()

print(res.summary())

print(res.params)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.77791D+00    |proj g|=  1.87352D-02
#
# At iterate    5    f=  3.77704D+00    |proj g|=  1.77258D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      9     14      1     0     0   0.000D+00   3.777D+00
#   F =   3.7770293451565569
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                ARMA Model Results
# ...

# %%
from statsmodels.tsa.arima_model import ARMA

mod = ARMA(vacation,order=(0,1))
res = mod.fit()

res.plot_predict(start='2015',end='2025')
pyplot.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %% [markdown]
# # Example furniture dataset

# %%
furn = read_csv('df_furniture.csv',header=0,index_col=0)
furn.head()
# Out:
#         furniture_price_adjusted
# Month
# 1/1/92               2073.432724
# 2/1/92               2114.485812
# 3/1/92               2260.570891
# 4/1/92               2255.103236
# 5/1/92               2331.414618

# %%
from statsmodels.tsa.arima_model import ARMA

mod = ARMA(furn,order=(0,1))
res = mod.fit()

print(res.summary())

print(res.params)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.52679D+00    |proj g|=  1.54857D-02
#
# At iterate    5    f=  8.52583D+00    |proj g|=  5.63105D-05
#
# At iterate   10    f=  8.52578D+00    |proj g|=  2.60787D-03
#
# At iterate   15    f=  8.52569D+00    |proj g|=  5.32907D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     18     32      1     0     0   7.105D-07   8.526D+00
#   F =   8.5256943470670414
#
# ...

# %%
from statsmodels.tsa.arima_model import ARMA

mod = ARMA(furn,order=(0,1))
res = mod.fit()

res.plot_predict(start='2015',end='2025')
pyplot.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %% [markdown]
# # Example 3: Bank of America dataset

# %%
bac = read_csv('df_bankofamerica.csv',index_col=0,parse_dates=True)
bac = bac.resample(rule='M').last()
bac.head()
# Out:
#             Adj Close Price
# Date
# 1990-01-31         1.542054
# 1990-02-28         1.687537
# 1990-03-31         1.469485
# 1990-04-30         1.441042
# 1990-05-31         1.525887

# %%
from statsmodels.tsa.arima_model import ARMA

mod = ARMA(bac,order=(0,1))
res = mod.fit()

print(res.summary())

print(res.params)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.22468D+00    |proj g|=  7.81748D-03
#
# At iterate    5    f=  3.22425D+00    |proj g|=  4.44089D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6     10      1     0     0   0.000D+00   3.224D+00
#   F =   3.2242481062688135
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                               ARMA Model Results
# ...

# %% [markdown]
# # Exercise 4: J.P.Morgan dataset

# %%
jpm = read_csv('df_jpmorgan.csv',index_col=0,parse_dates=True)
jpm = jpm.resample(rule='Q').last()
jpm.head()
# Out:
#             Adj Close Price
# Date
# 1990-03-31         2.884144
# 1990-06-30         3.223591
# 1990-09-30         2.019471
# 1990-12-31         1.427535
# 1991-03-31         2.340254

# %%
from statsmodels.tsa.arima_model import ARMA

mod = ARMA(jpm,order=(0,1))
res = mod.fit()

print(res.summary())

print(res.params)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.18671D+00    |proj g|=  9.99982D-03
#
# At iterate    5    f=  4.18570D+00    |proj g|=  2.51728D-03
#
# At iterate   10    f=  4.18559D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     12     14      1     0     0   0.000D+00   4.186D+00
#   F =   4.1855947704995424
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ...

# %%
from statsmodels.tsa.arima_model import ARMA

mod = ARMA(jpm,order=(0,1))
res = mod.fit()

res.plot_predict(start='2015',end='2025')
pyplot.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
#  This problem is unconstrained.
# ...

# %% [markdown]
# # Example 5: Average Temperature of St.Louis dataset

# %%
#make necesarry imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from math import sqrt
import sys, os
from contextlib import contextmanager
import matplotlib as mpl
import seaborn as sns
import sklearn
from matplotlib import pyplot

# %%
#Read in temp dataset
temp = read_csv('df_temp.csv', index_col=0, parse_dates=True)
temp.head()
# Out:
#             Value
# Date
# 1938-04-01   56.5
# 1938-05-01   64.7
# 1938-06-01   73.5
# 1938-07-01   80.4
# 1938-08-01   81.3

# %%
#Estimate Moving Average
#Import the ARMA module from statsmodels
from statsmodels.tsa.arima_model import ARMA
#Fit an MA(1) model to the first simulated data
mod=ARMA(temp, order=(0,1))#order is reversed for MA compared to AR, MA(1)
res=mod.fit()
#Print out summary information on the fit
print(res.summary())
#Print out the estimate for the coefficients
print(res.params)
#S.D. of innovations is standard deviation of errors
#L1 is lagl
#fitted model parameters, MA lag1
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.83631D+00    |proj g|=  3.18146D-04
#
# At iterate    5    f=  3.83631D+00    |proj g|=  3.09086D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      9     11      1     0     0   0.000D+00   3.836D+00
#   F =   3.8363063196411136
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                               ARMA Model Results
# ...

# %%
#Forecast Moving Average Model
#Import the ARMA module from statsmodels
from statsmodels.tsa.arima_model import ARMA
#Forecast the first MA(1) model
mod=ARMA(temp, order=(0,1))
res=mod.fit()
#Start the forecast 10 data points before the end of the point series at,
#and end the forecast 10 data points after the end of the series at point
res.plot_predict(start='2015', end='2025')
pyplot.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %% [markdown]
# # I. Exercise

# %%
# Working with ML models for Time Series Analysis

# %%
import pandas as pd
from pandas import read_csv
from matplotlib import pyplot

# %%
# Example 1: Vacation Dataset

# %%
#Read in data asapanda series
#https://trends.google.com/trends/?geo-US, google trends, search the word "vacation"
#Recall that data is from 2004 to 2019
vacation=pd.read_csv('vacation_firstdiff.csv', index_col=0, parse_dates=True)

# %%
#display first few rows
print (vacation.head(5))
#line plot of dataset
vacation.plot (figsize (8,5))
pyplot.show ()
#data is monthly and is made stationary
# Out:
#             first_diff
# Month
# 2004-04-01        -7.0
# 2004-05-01        10.0
# 2004-06-01         9.0
# 2004-07-01        -2.0
# 2004-08-01       -17.0

# %%
vacation.describe()
# Out:
#        first_diff
# count  187.000000
# mean    -0.262032
# std      9.853813
# min    -23.000000
# 25%     -6.000000
# 50%     -1.000000
# 75%      5.000000
# max     33.000000

# %%
# Kernel Density Plot

# %%
vacation.plot (kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Autocorrelation Plot

# %%
from statsmodels.graphics.tsaplots import plot_acf
#Check for autocorrelation of each lagged observation and whether it is statistically significant.
plot_acf(vacation)
pyplot.show()

# %%
# Create Lagged Variables

# %%
from pandas import DataFrame

#reframe as supervised learning
#lag observation (t-1) is the input variable andtis the output variable.
df1 = DataFrame()
print(df1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Create 12 months of lag values to predict current observation
#Shift of 12 months
for i in range(12,0,-1):
    df1[['t-'+str(i)]] = vacation.shift(i)
print(df1)
# Out:
#             t-12  t-11  t-10   t-9   t-8   t-7   t-6  t-5   t-4   t-3   t-2  \
# Month
# 2004-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN
# 2004-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN
# 2004-06-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN   NaN   NaN  -7.0
# 2004-07-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN   NaN  -7.0  10.0
# 2004-08-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  -7.0  10.0   9.0
# ...          ...   ...   ...   ...   ...   ...   ...  ...   ...   ...   ...
# 2019-06-01   9.0  -1.0 -11.0 -12.0  -1.0   4.0  15.0 -3.0  -3.0   0.0  -4.0
# 2019-07-01  -1.0 -11.0 -12.0  -1.0   4.0  15.0  -3.0 -3.0   0.0  -4.0   1.0
# 2019-08-01 -11.0 -12.0  -1.0   4.0  15.0  -3.0  -3.0  0.0  -4.0   1.0  11.0
# 2019-09-01 -12.0  -1.0   4.0  15.0  -3.0  -3.0   0.0 -4.0   1.0  11.0  -2.0
# 2019-10-01  -1.0   4.0  15.0  -3.0  -3.0   0.0  -4.0  1.0  11.0  -2.0 -11.0
#
#              t-1
# Month
# 2004-04-01   NaN
# ...

# %%
#Create columnt
df1['t'] = vacation.values
print(df1.head(13))
# Out:
#             t-12  t-11  t-10   t-9   t-8   t-7   t-6   t-5   t-4   t-3   t-2  \
# Month
# 2004-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2004-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2004-06-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  -7.0
# 2004-07-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  -7.0  10.0
# 2004-08-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  -7.0  10.0   9.0
# 2004-09-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN  -7.0  10.0   9.0  -2.0
# 2004-10-01   NaN   NaN   NaN   NaN   NaN   NaN  -7.0  10.0   9.0  -2.0 -17.0
# 2004-11-01   NaN   NaN   NaN   NaN   NaN  -7.0  10.0   9.0  -2.0 -17.0 -18.0
# 2004-12-01   NaN   NaN   NaN   NaN  -7.0  10.0   9.0  -2.0 -17.0 -18.0  -1.0
# 2005-01-01   NaN   NaN   NaN  -7.0  10.0   9.0  -2.0 -17.0 -18.0  -1.0   3.0
# 2005-02-01   NaN   NaN  -7.0  10.0   9.0  -2.0 -17.0 -18.0  -1.0   3.0   4.0
# ...

# %%
#Createanew subsetted dataframe, removing Nans from first 12 rows
dfl_vacat =  df1[13:]
print(dfl_vacat)
# Out:
#             t-12  t-11  t-10   t-9   t-8   t-7   t-6   t-5   t-4   t-3   t-2  \
# Month
# 2005-05-01  10.0   9.0  -2.0 -17.0 -18.0  -1.0   3.0   4.0  33.0  -6.0  -3.0
# 2005-06-01   9.0  -2.0 -17.0 -18.0  -1.0   3.0   4.0  33.0  -6.0  -3.0 -11.0
# 2005-07-01  -2.0 -17.0 -18.0  -1.0   3.0   4.0  33.0  -6.0  -3.0 -11.0   3.0
# 2005-08-01 -17.0 -18.0  -1.0   3.0   4.0  33.0  -6.0  -3.0 -11.0   3.0  13.0
# 2005-09-01 -18.0  -1.0   3.0   4.0  33.0  -6.0  -3.0 -11.0   3.0  13.0  -4.0
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2019-06-01   9.0  -1.0 -11.0 -12.0  -1.0   4.0  15.0  -3.0  -3.0   0.0  -4.0
# 2019-07-01  -1.0 -11.0 -12.0  -1.0   4.0  15.0  -3.0  -3.0   0.0  -4.0   1.0
# 2019-08-01 -11.0 -12.0  -1.0   4.0  15.0  -3.0  -3.0   0.0  -4.0   1.0  11.0
# 2019-09-01 -12.0  -1.0   4.0  15.0  -3.0  -3.0   0.0  -4.0   1.0  11.0  -2.0
# 2019-10-01  -1.0   4.0  15.0  -3.0  -3.0   0.0  -4.0   1.0  11.0  -2.0 -11.0
#
#              t-1     t
# Month
# ...

# %%
#save to new file
dfl_vacat.to_csv('vacation_lags_12months_features.csv', index=False)

# %%
# Example 2: Furniture Dataset

# %%
furniture=pd.read_csv('furn_pctchange.csv', index_col=0, parse_dates=True)
furniture.head ()
#data is monthly and made stationary
# Out:
#             furniture_pct_change
# Month
# 1992-02-01              0.019800
# 1992-03-01              0.069088
# 1992-04-01             -0.002419
# 1992-05-01              0.033839
# 1992-06-01              0.022829

# %%
#line plot of dataset
furniture.plot (figsize (8,5))
pyplot.show()

# %%
furniture.describe ()
# Out:
#        furniture_pct_change
# count            330.000000
# mean               0.009588
# std                0.094790
# min               -0.284492
# 25%               -0.032020
# 50%                0.022959
# 75%                0.073826
# max                0.179970

# %% [markdown]
# # Kernel Density Plot

# %%
furniture.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Autocorrelation Plot

# %%
from statsmodels.graphics.tsaplots import plot_acf
#Check for autocorrelation of each lagged observation and whether it is statistically significant.
plot_acf(furniture)
pyplot.show()

# %% [markdown]
# # Create Lagged Variables

# %%
from pandas import DataFrame
#reframe as supervised learning
#lab observation (t-1) is the input variable andt is the output variable.
df2 = DataFrame ()
#print (df2)

# %%
#Create 12 months of lag values to predict current observation
#Shift of l12 months
for i in range (12,0,-1):
    df2[['t-'+str(i)]] = furniture.shift(i)
print(df2)
# Out:
#                 t-12      t-11      t-10       t-9       t-8       t-7  \
# Month
# 1992-02-01       NaN       NaN       NaN       NaN       NaN       NaN
# 1992-03-01       NaN       NaN       NaN       NaN       NaN       NaN
# 1992-04-01       NaN       NaN       NaN       NaN       NaN       NaN
# 1992-05-01       NaN       NaN       NaN       NaN       NaN       NaN
# 1992-06-01       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2019-03-01  0.179970 -0.080049  0.084601 -0.018317 -0.001271  0.049036
# 2019-04-01 -0.080049  0.084601 -0.018317 -0.001271  0.049036 -0.060266
# 2019-05-01  0.084601 -0.018317 -0.001271  0.049036 -0.060266  0.017193
# 2019-06-01 -0.018317 -0.001271  0.049036 -0.060266  0.017193  0.084769
# 2019-07-01 -0.001271  0.049036 -0.060266  0.017193  0.084769  0.033371
#
#                  t-6       t-5       t-4       t-3       t-2       t-1
# Month
# ...

# %%
#Create columnt
df2['t']=furniture.values
print(df2.head(13))
# Out:
#               t-12      t-11      t-10       t-9       t-8       t-7  \
# Month
# 1992-02-01     NaN       NaN       NaN       NaN       NaN       NaN
# 1992-03-01     NaN       NaN       NaN       NaN       NaN       NaN
# 1992-04-01     NaN       NaN       NaN       NaN       NaN       NaN
# 1992-05-01     NaN       NaN       NaN       NaN       NaN       NaN
# 1992-06-01     NaN       NaN       NaN       NaN       NaN       NaN
# 1992-07-01     NaN       NaN       NaN       NaN       NaN       NaN
# 1992-08-01     NaN       NaN       NaN       NaN       NaN       NaN
# 1992-09-01     NaN       NaN       NaN       NaN       NaN  0.019800
# 1992-10-01     NaN       NaN       NaN       NaN  0.019800  0.069088
# 1992-11-01     NaN       NaN       NaN  0.019800  0.069088 -0.002419
# 1992-12-01     NaN       NaN  0.019800  0.069088 -0.002419  0.033839
# 1993-01-01     NaN  0.019800  0.069088 -0.002419  0.033839  0.022829
# ...

# %%
#Createanew subsetted dataframe, removing Nans from first 12 row
df2_furn = df2[13:] 
print (df2_furn)
# Out:
#                 t-12      t-11      t-10       t-9       t-8       t-7  \
# Month
# 1993-03-01  0.069088 -0.002419  0.033839  0.022829  0.013640  0.011722
# 1993-04-01 -0.002419  0.033839  0.022829  0.013640  0.011722 -0.023777
# 1993-05-01  0.033839  0.022829  0.013640  0.011722 -0.023777  0.042725
# 1993-06-01  0.022829  0.013640  0.011722 -0.023777  0.042725  0.043720
# 1993-07-01  0.013640  0.011722 -0.023777  0.042725  0.043720  0.127219
# ...              ...       ...       ...       ...       ...       ...
# 2019-03-01  0.179970 -0.080049  0.084601 -0.018317 -0.001271  0.049036
# 2019-04-01 -0.080049  0.084601 -0.018317 -0.001271  0.049036 -0.060266
# 2019-05-01  0.084601 -0.018317 -0.001271  0.049036 -0.060266  0.017193
# 2019-06-01 -0.018317 -0.001271  0.049036 -0.060266  0.017193  0.084769
# 2019-07-01 -0.001271  0.049036 -0.060266  0.017193  0.084769  0.033371
#
#                  t-6       t-5       t-4       t-3       t-2       t-1  \
# Month
# ...

# %%
#save to new file
df2_furn.to_csv('furniture_lags 12months_features.csv', index=False)
